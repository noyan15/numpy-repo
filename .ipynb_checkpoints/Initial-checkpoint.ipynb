# %%
import numpy as np
print('hi')

x = np.array([[1,2,3],[1,2,3]])
print(x)
# Out:
# hi
# [[1 2 3]
#  [1 2 3]]

# %%
import numpy as np
x = [1,2,3,4]
y = np.array(x)

print(x,y)
# Out:
# [1, 2, 3, 4] [1 2 3 4]

# %%
arr = []
for i in range(1,6):
    j = str(i)
    num = input("Enter number " + j + ": ")
    try:
        num = int(num)
        arr.append(num)
    except:
        print("not a numeric value")
print(arr)
# Out:
# Enter number 1:  21
# Enter number 2:  12
# Enter number 3:  e
# not a numeric value
# Enter number 4:  21
# Enter number 5:  4
# [21, 12, 21, 4]
