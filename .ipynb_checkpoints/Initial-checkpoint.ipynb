# %%
import numpy as np
print('hi')

x = np.array([[1,2,3],[1,2,3]])
print(x)
# Out:
# hi
# [[1 2 3]
#  [1 2 3]]

# %%
import numpy as np
x = [1,2,3,4]
y = np.array(x)

print(x,y)
# Out:
# [1, 2, 3, 4] [1 2 3 4]
